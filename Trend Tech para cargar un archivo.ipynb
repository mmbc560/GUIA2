# %% [markdown]
# <a href="https://colab.research.google.com/github/mmbc560/GUIA2/blob/main/Trend%20Tech%20para%20cargar%20un%20archivo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# Al ejecutar esta celda aparecerá el botón "Choose Files" o "Seleccionar archivos"
uploaded = files.upload()
