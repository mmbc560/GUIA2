# %% [markdown]
# <a href="https://colab.research.google.com/github/mmbc560/GUIA2/blob/main/1_PRACTICE_FROM_BUSINESS_PROBLEM_TO_ANALYTICS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# PRACTICE - FROM BUSINESS PROBLEM TO ANALYTICS
# ============================================================

PROJECT_NAME = ""

BUSINESS_PROBLEM = """
"""

MANAGERIAL_DECISION = """
"""

# Main result to understand, explain, predict or improve
TARGET_VARIABLE_Y = ""

# Possible factors associated with Y
POSSIBLE_DRIVERS_X = [
    "",
    "",
    "",
    "",
    ""
]

KPIS = [
    "",
    "",
    ""
]

DATA_REQUIRED = [
    "",
    "",
    "",
    "",
    ""
]

ANALYTICS_QUESTION = """
"""

# ============================================================
# DISPLAY YOUR ANALYTICS MAP
# ============================================================

print("BUSINESS PROBLEM:")
print(BUSINESS_PROBLEM)

print("\nMANAGERIAL DECISION:")
print(MANAGERIAL_DECISION)

print("\nTARGET VARIABLE (Y):")
print(TARGET_VARIABLE_Y)

print("\nPOSSIBLE DRIVERS (X):")
for x in POSSIBLE_DRIVERS_X:
    print("-", x)

print("\nKPIs:")
for kpi in KPIS:
    print("-", kpi)

print("\nDATA REQUIRED:")
for data in DATA_REQUIRED:
    print("-", data)

print("\nANALYTICS QUESTION:")
print(ANALYTICS_QUESTION)
